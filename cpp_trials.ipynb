# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
C0 = np.loadtxt('test1\C_trap-free_L=1000_N=51_t=0.txt')
C100 = np.loadtxt('test1\C_trap-free_L=1000_N=51_t=100.txt')
C1000 = np.fromfile('test1/bintest2.bin').reshape(1000,1000)
C10002 = np.loadtxt('test1\C_trap-free_L=1000_N=51_t=1000.txt')
# with open("test1/bintest2.bin", mode='rb') as file:
#     C1000 = file.read()
x = np.linspace(0,999,1000)
plt.plot(x,np.diag(C0))
plt.plot(x,np.diag(C100))
plt.plot(x,np.diag(C1000))
plt.plot(x,np.diag(C10002),linestyle='--')

# %%
C0 = np.fromfile('trap_to_free_T=0/C_trap-free_L=1000_N=51_t=0.bin').reshape(1000,1000)
C500 = np.fromfile('trap_to_free_T=0/C_trap-free_L=1000_N=51_t=500.bin').reshape(1000,1000)
C1000 = np.fromfile('trap_to_free_T=0/C_trap-free_L=1000_N=51_t=1000.bin').reshape(1000,1000)
x = np.linspace(0,999,1000)

# %%
x = np.linspace(0,999,1000)
for t in range(0,1,10):
    plt.plot(x,np.diag(np.fromfile('Bragg_quench/C_free-bragg_L=1000_N=51_t='+str(t)+'.bin').reshape(1000,1000)))
